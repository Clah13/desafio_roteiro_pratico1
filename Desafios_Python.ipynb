# %% [markdown]
# <a href="https://colab.research.google.com/github/Clah13/desafio_roteiro_pratico1/blob/main/Desafios_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Desafios
#
# Realize os exercícios listados abaixo e crie um repositório para eles.

# %% [markdown]
# ## 1. Desafio 01
#
#   Você possui algumas variáveis em Python que descrevem alguns dos seus atributos. Com base nessas variáveis, gere uma apresentação curta de si mesmo.
#
#   ```
#   nome = "Rodolfo"
#   idade = 40
#   cidade = "Diadema"
#
#   "Olá! Meu nome é Rodolfo. Eu tenho 40 anos e moro em Diadema."
#
#   ```

# %%
# Registra a informação na variável com base no que o usuário digita

print("==== Programa Apresente-se ====")
nome = input("Digite o seu nome: ")
idade = input("Digite a sua idade: ")
cidade = input("Digite a cidade onde mora: ")

# Mostra para o usuário as informações salvas

print(f"Olá! Meu nome é {nome}. Eu tenho {idade} anos e moro em {cidade}.")
# Out:
# ==== Programa Apresente-se ====
# Digite o seu nome: Clarice
# Digite a sua idade: 31
# Digite a cidade onde mora: Santo André
# Olá! Meu nome é Clarice. Eu tenho 31 anos e moro em Santo André.

# %% [markdown]
# ## 1.1 Erros cometidos neste exercício
#
#   Nenhum erro foi cometido. Hooray! 🙂

# %% [markdown]
# ## 2. Desafio 02
#
#   Dada uma lista de números em Python, Calcule a média dos valores dessa lista.
#
#   ```
#   numeros = [10, 20, 30, 40, 50]
#
#   ```

# %% [markdown]
# ## 2.1 Média Simples
#
#   Código simples e direto ao ponto para cálculo da média com os elementos fornecidos pelo exercício.
#
#   Considerando que os números são estáticos, a soma sempre será 150 e a média correta a ser alcançada é 30.
#
#   `150 / 5 = 30`.

# %%
numeros = [10,20,30,40,50] #Valores fixos já estabelecidos no código

# Função para calcular a média
def media(elementos):

  calculo = sum(elementos) / len(elementos) #Fiz o 2.2 antes do 2.1. Aqui está mais enxuto.

  return calculo
print("==== Programa Calcula Média ====")
print("A média é:", media(numeros))
# Out:
# ==== Programa Calcula Média ====
# A média é: 30.0

# %% [markdown]
# ### 2.2 - Média dinâmica
#
#   Considerando que é um desafio, construí uma versão que suporta múltiplos tamanhos de lista, que é escolhida pelo usuário. Além disso, os números gerados são aleatórios até 100.

# %%
from random import randrange

# Variável de lista vazia
lista = []

# Função para adicionar números aleatórios à lista
def adiciona(nome_lista, tamanho):

  for i in range(tamanho): # Itera para adicionar os elementos na lista

    nome_lista.append(randrange(0, 101)) #101 não incluso no random

  return nome_lista

# Soma e tira a média dos números da lista
def calcula(nome_lista):

  soma = sum(nome_lista)
  print("Soma:", soma) # Imprime a soma pra fins de validação e teste

  media = soma / len(nome_lista) # Divide pelo tamanho da lista no cálculo da média
  '''
  Aqui eu também poderia colocar como media = soma / tamanho (variável tamanho),
   mas optei por não adicionar para evitar que eu tivesse que incluir o tamanho
   como parâmetro nesta função.
  Ao invés disso, optei por usar o tamanho da lista já que estava disponível para
   ser calculado. Isso também permite manter o cálculo correto da média caso a
   lista seja modificada novamente por alguma outra função durante a execução do
   programa - seja com a adição ou remoção de elementos.
  '''

  return media

# Executa as funções e imprime
print("==== Programa Calcula Média Dinâmica ====")

# O usuário escolhe o tamanho da lista a ser gerada
print("Digite o tamanho: ")
tamanho = int(input())

print("Valores adicionados:", adiciona(lista, tamanho))
print("Média:", calcula(lista))
# Out:
# ==== Programa Calcula Média Dinâmica ====
# Digite o tamanho:
# 10
# Valores adicionados: [13, 51, 89, 32, 44, 32, 81, 63, 23, 26]
# Soma: 454
# Média: 45.4

# %% [markdown]
# ## 2.3 Erros cometidos neste exercício
#
# - Tive dificuldades em entender a necessidade de separação das variáveis dentro e fora da função;
#
# - Errei várias vezes a sintaxe para geração dos números randomicos (tive que procurar na documentação pra conseguir fazer o que queria);
#
# - Errei na hora de imprimir os valores. Ora mostrava onde ficava na memória, ora tentava imprimir com as variáveis temporárias na função.

# %% [markdown]
# ## 3. Desafio 03
#
#   Você possui duas listas de Python. Cada lista representa os gastos do mês de dois amigos, João e Pedro. Cada valor na lista representa o gasto em uma das semanas do mês. Seu objetivo é encontrar quem gastou mais dinheiro ao longo do mês, João ou Pedro. Para isso, crie um código em Python que responda a essa pergunta.
#
#   ```
#   gastos_rodolfinho = [300, 500, 200, 800]
#   gastos_rodolfao = [200, 400, 500, 700]
#
#   ```

# %% [markdown]
# ## 3.1 - Cálculo de lista estática
#
#   Seguindo a mesma lógica do exercício 2.1, segue como eu faria o exercício de código simples e prático, caso a lista seja com valores estáticos ou inclusa diretamente no código, sem o input do usuário.

# %%
# Valores que cada pessoa gastou

Joao = [300, 500, 200, 800]
Pedro = [200, 400, 500, 700]

# Função para calcular o gasto (eu fiz esse negócio em 2 minutos depois do sofrimento no item 3.2 hahaha)

def calculaGasto(lista1, lista2):
  valorl1 = sum(lista1) # soma valores da lista 1 (Joao)
  valorl2 = sum(lista2) # soma valores da lista 2 (Pedro)

  if valorl1 > valorl2: # compara valores e declara vencedor
    vencedor = "João! Parabéns, seu gastão!"

  elif valorl2 > valorl1: # compara valores e declara vencedor
    vencedor = "Pedro! Parabéns, seu gastão!"

  else: # caso de empate
    vencedor = "Vish, empatou! Hora de melhorar esse planejamento financeiro, hein..."

  # resultado
  print(f"João gastou R${valorl1} no mês e Pedro gastou R${valorl2} no mês. Nosso vencedor nos gastos é...\n {vencedor}")

# Main (execução da função)
calculaGasto(Joao, Pedro)
# Out:
# João gastou R$1800 no mês e Pedro gastou R$1800 no mês. Nosso vencedor nos gastos é...
#  Vish, empatou! Hora de melhorar esse planejamento financeiro, hein...

# %% [markdown]
# ## 3.2 - Registro dinâmico de valores
#
#   Segundo a mesma lógica do tópico 2.2, tentei me desafiar ao máximo para que o programa funcionasse majoritariamente com o input do usuário e considerasse elementos aprendidos em aula, como de funções, gerenciamento das listas, loops, adição e remoção dos valores.
#
#   Outros elementos disponíveis na linguagem também acabaram sendo implementados durante a minha pesquisa para melhorar o código, como o try except, filtros, lambda, dentre outros.

# %%
#Listas que armazenarão as informações de clientes e valores

cadastro01 = []
cadastro02 = []

# Função telaInicial - loop while que itera as opções do menu. A única forma de sair é pressionando 5
def telaInicial():
  while True:
    print("""
    ---------------------------------------

    Por favor, selecione a opção desejada:

    1 - Cadastrar-se
    2 - Registrar consumo
    3 - Estatísticas de valores devidos
    4 - Limpar registros
    5 - Sair
    ---------------------------------------
    """)
    escolha = input("> ")

    # "Switch case": Cada opção leva para outra função. Uma para o cadastro da pessoa,
    # outra para o cadastro do consumo, outra pra fazer a soma do que foi
    # consumido por cada pessoa e por fim uma para apagar um ou mais valores registrados.

    match escolha:
      case "1":
        cadastro()

      case "2":
        cadastroConsumo()

      case "3":
        calcConsumo()

      case "4":
        apagar()

      case "5":
        print("Até a próxima!")
        return False #quebra o loop

      case _: #genérico - "outros"
        print("\nOpção inválida. Tente novamente.")
  return True

# Função cadastro, que é responsável por forçar o usuário a cadastrar, obrigatoriamente, duas pessoas.
# No início, coloquei para cadastrar uma pessoa por vez, mas com o objetivo de terminar isso logo eu modifiquei
# o código para que as duas pessoas fossem cadastradas uma após a outra.

# Caso uma pessoa seja apagada, o cadastro só será feito do ID que ficou em branco. :)
# Obs: ainda possui recursividade, mas estou programando desde 06h da manhã e agora são 21:13. Não tenho mais energia pra modificar esse código por while e testar.

def cadastro():

  if cadastro01 == []: # se estiver vazio
    print("\n~~ CADASTRO 01 ~~")
    nome = input("Por favor, digite o seu nome: > ")
    cadastro01.append(nome) #adiciona à lista
    # ponto de atenção: não há validação do nome, então aqui aceita qualquer coisa, inclusive números. Apesar de existir um filtro por int e float, e aqui ser tecnicamente string, não testei se afeta a soma.

    # mensagem de feedback
    print("\n______________\n")
    print("Cadastro realizado com sucesso! Seu ID é 01.")
    print("______________\n\n")
    print("Prosseguindo para o próximo cadastro...\n\n")
    cadastro()

  elif cadastro02 == []: # se estiver vazio
    print("~~ CADASTRO 02 ~~")
    nome = input("Por favor, digite o seu nome: > ")
    cadastro02.append(nome) # adiciona à lista
    # ponto de atenção: não há validação do nome, então aqui aceita qualquer coisa, inclusive números. Apesar de existir um filtro por int e float, e aqui ser tecnicamente string, não testei se afeta a soma.

    # mensagem de feedback
    print("\n______________\n")
    print("Cadastro realizado com sucesso! Seu ID é 02.")
    print("______________\n\n")
    print("Voltando para a tela inicial...\n")

  else: # se nenhuma lista estiver vazia
    # mensagem de feedback
    print("\n______________\n")
    print("Cadastro de 02 pessoas realizado com sucesso!")
    print("______________\n\n")
    print("Voltando para a tela inicial...\n")

# Função "cadê o cadastro?" que puxa a orelha do usuário e retorna uma mensagem de erro genérica
# se não houve um cadastro prévio nas opções 02 e 03.
# Poderia implementar o mesmo na opção 04 (apagar) mas não deu tempo.

def cadeCadastro():

  print("\n****\nATENÇÃO: Não é possível registrar nem calcular o consumo de pessoas não cadastradas! Realize o cadastro de DUAS pessoas primeiro e tente novamente.\n****\n")
  cadastro() # chama a função cadastro para completar o cadastro do usuário.

# Função cadastroConsumo, que é responsável por registrar o que foi gasto pelo usuário.
# Primeiro, valida se o cadastro foi completo para depois sinalizar as opções.
# A validação dos usuários evita que o índice 0 fique nulo ou vazio.
# Após o usuário confirmar qual o cadastro, ele registra o valor gasto.
# É possível melhorar ainda mais o loop para que o mesmo usuário cadastre novos valores repetidamente até que ele peça para sair, mas no momento vai ficar assim.

def cadastroConsumo():
  if cadastro01 == [] or cadastro02 == []:
    cadeCadastro()
    return

  while True:
    cadastralista = input("""
    ........................\n
    Por favor, selecione o usuário a ter o consumo cadastrado:
    1 - """ + cadastro01[0] + """
    2 - """ + cadastro02[0] + """
    3 - Voltar\n
    ........................\n
    """) # O primeiro item da lista sempre será o nome cadastrado do usuário

    if cadastralista == "1":
      valor = input("\nSelecione o valor da despesa a ser cadastrada: ")
      try: # Try catch / try except para registros de valores que não são números
        validacao = float(valor)

        if validacao < 0: # Validação adicional. Valor numérico também não pode ser negativo
          print("\nO valor não pode ser menor que zero.")
          continue

        cadastro01.append(float(valor)) # Adiciona à lista 01
        print("\nCadastro realizado com sucesso!")

      except ValueError: # Em caso de erro
        print ("\n** Formato inválido. Por favor, tente novamente e utilize apenas números com ponto na casa decimal.**\n")

    elif cadastralista == "2":
      valor = input("\nSelecione o valor da despesa a ser cadastrada: ")
      try: # Try catch / try except para registros de valores que não são números
        validacao = float(valor)

        if validacao < 0: # Validação adicional. Valor numérico também não pode ser negativo
          print("\nO valor não pode ser menor que zero.")
          continue

        cadastro02.append(float(valor)) # Adiciona à lista 02
        print("\nCadastro realizado com sucesso!")

      except ValueError: # Em caso de erro
        print ("\n** Formato inválido. Por favor, tente novamente e utilize apenas números com ponto na casa decimal.**\n")

    elif cadastralista == "3": # Retornar para o menu
      print ("\n** Voltando para a tela inicial... **\n")
      return

    else: #Outras possibilidades de preenchimento incorreto
      print("\n_____________\n")
      print("Opção inválida. Tente novamente ou digite 3 para voltar.")
      print("_____________")

# Função calcConsumo
# Basicamente filtra o que não for número inteiro ou float da nossa lista e soma os valores filtrados.
# Contém tratativa de erros para cobrir possibilidade de valores zerados ou não preenchidos.
# Informa ao usuário quem dos usuários registrados gastou mais ou se ambos gastaram o mesmo valor.

def calcConsumo():
  if cadastro01 == [] or cadastro02 == []: # Verifica se existe usuário em branco
    cadeCadastro()

  consumo1 = sum(list(filter(lambda x: isinstance(x, (int, float)) and not isinstance(x, bool), cadastro01))) # Filtra os valores da lista 01 para mostrar apenas int e float. Como boleano é considerado um número [0,1], o filtra também.
  # Soma os valores após a filtragem.

  if consumo1 == 0: # Se nenhum valor for cadastrado, retornará zero. Valida se é zero ou não.
    print(cadastro01[0],", você não possui gastos registrados!")

  else:
    print("\nO consumo de "+ cadastro01[0] + " é:", consumo1) #Informa o consumo

  consumo2 = sum(list(filter(lambda x: isinstance(x, (int, float)) and not isinstance(x, bool), cadastro02))) # Filtra os valores da lista 02 para mostrar apenas int e float. Como boleano é considerado um número [0,1], o filtra também.
  # Soma os valores após a filtragem.

  if consumo2 == 0: # Se nenhum valor for cadastrado, retornará zero. Valida se é zero ou não.
    print(cadastro02[0],", você não possui gastos registrados!")

  else: # Informa o consumo
    print("\nO consumo de " + cadastro02[0] + " é:", consumo2)

  # Comparação de valores
  if consumo1 > consumo2:
    print("\nA pessoa que mais gastou é: " + cadastro01[0])

  elif consumo2 > consumo1:
    print("\nA pessoa que mais gastou é " + cadastro02[0])

  else:
    print("\nO consumo foi do mesmo valor.")

  # Mensagem informativa avisando que os valores não são armazenados em nenhum lugar fixo/banco de dados.
  print("\nOs dados serão automaticamente apagados após a finalização do programa.")

# Função apagar
# Funciona em loop while e apaga todo o registro da lista selecionada.
# Há validação caso a lista esteja vazia.
# Obs: o código poderia ser melhorado colocando a validação da lista antes do usuário
# selecionar a opção desejada, para que ele apague apenas de fato o que precisar.
# Neste momento, mesmo com a lista vazia, há a opção de apagar.

def apagar():
  while True:

    apagalista = input("""
    Por favor, selecione o ID do usuário a ser apagado:
    1 - ID 01
    2 - ID 02
    3 - Voltar\n
    """)
    print() # Opção por ID ao invés de nome pois pode existir uma lista já vazia.

    if apagalista == "1": # Validação se existem valores a serem apagados.
      if len(cadastro01) == 0:
        print("\n_____________\n")
        print("Não há informação a ser apagada.")
        print("_____________")

      else:
        cadastro01.clear() # Comando de apagar a lista
        print("\n_____________\n")
        print("Operação realizada com sucesso!")
        print("_____________\n")

    elif apagalista == "2":

      if len(cadastro02) == 0: # Validação se existem valores a serem apagados.
        print("\n_____________\n")
        print("Não há informação a ser apagada.")
        print("_____________\n")

      else:
        cadastro02.clear() # Comando de apagar a lista
        print("\n_____________\n")
        print("Operação realizada com sucesso!")
        print("_____________\n")

    elif apagalista == "3": # Voltando pra tela inicial
      print("\n** Voltando para a tela inicial... **\n")
      return #Sai desse loop e volta para o da tela inicial.

    else: #Tratativa de erro para opções inválidas.
      print("\n_____________\n")
      print("Opção inválida. Tente novamente ou digite 3 para voltar.")
      print("_____________\n")

# ____________________________________
# Execução do código principal (main)


print("======== REGISTRO E COMPARAÇÃO DE GASTOS 'DUPLA DINÂMICA' ==========")

print()

print("Olá, seja bem-vindo(a) ao nosso sistema de controle de gastos!")
print("Recomenda-se como primeiro passo realizar o cadastro de DUAS pessoas.")

telaInicial() #Chama o loop da tela inicial.
print("___") # Toque para finalização.
# Out:
# ======== REGISTRO E COMPARAÇÃO DE GASTOS 'DUPLA DINÂMICA' ==========
#
# Olá, seja bem-vindo(a) ao nosso sistema de controle de gastos!
# Recomenda-se como primeiro passo realizar o cadastro de DUAS pessoas.
#
#     ---------------------------------------
#
#     Por favor, selecione a opção desejada:
#
#     1 - Cadastrar-se
#     2 - Registrar consumo
#     3 - Estatísticas de valores devidos
#     4 - Limpar registros
#     5 - Sair
#     ---------------------------------------
#
# > 1
# ~~ CADASTRO 01 ~~
# Por favor, digite o seu nome: > Maria
#
# ______________
#
# Cadastro realizado com sucesso! Seu ID é 01.
# ______________
#
#
# Prosseguindo para o próximo cadastro...
#
#
# ~~ CADASTRO 02 ~~
# Por favor, digite o seu nome: > Clarice
#
# ______________
#
# Cadastro realizado com sucesso! Seu ID é 02.
# ______________
#
#
# Voltando para a tela inicial...
#
#
#     ---------------------------------------
#
#     Por favor, selecione a opção desejada:
#
#     1 - Cadastrar-se
# ...

# %% [markdown]
# ## 3.3 - Erros cometidos nesse exercício
#   - Originalmente havia feito muitas opções recursivas (função chamando outra que chamava outra). Acabei trocando por loops while.
#   - Errei bastante a sintaxe do filtro com o lambda;
#   - Perdi a conta de quantos loops infinitos ocorreram por falta de atenção no posicionamento do código;
#   - Esqueci de registrar outros erros que ocorreram, mas foram vários.
#   - Não é necessariamente um erro, apenas uma observação. Originalmente estava usando o sys.exit() para finalizar o programa, mas como gerava uma exceção no colab optei por encerrar via while com um retorno 'False'. Está explicado no código.
